# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranil199/100-days-of-code_py/blob/main/CB_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numbers
#
# In Python, numbers aren't just primitive data types; they are first-class objects designed to be intuitive for beginners while offering immense power for data scientists and engineers.

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*1
# Out:
# 2

# %%
2/1
# Out:
# 2.0

# %%
1/2
# Out:
# 0.5

# %%
#Modulo or "Mod" Operator

# %%
7/4
# Out:
# 1.75

# %%
7 % 4 #Mod operator to find the remider post division
# Out:
# 3

# %%
7%2 # %2 to find to if the number is even or not, if its even then there should be no reminder
# Out:
# 1

# %%
2**3
# Out:
# 8

# %%
2+10*10+3
# Out:
# 105

# %%
(2+10) * (10+3)
# Out:
# 156

# %% [markdown]
# Variable

# %%
print("Hello")
# Out:
# Hello

# %%
for i in range(5):
  print(i*i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
Food= 'jalebi'
Food
# Out:
# 'jalebi'

# %%
bar=Food

# %%
id(Food)
# Out:
# 135481988006848

# %%
bar
# Out:
# 'jalebi'

# %%
id(bar)
# Out:
# 135481988006848

# %%
bar='Samosa'

# %%
bar
# Out:
# 'Samosa'

# %%
id(bar)
# Out:
# 135481557826608

# %%
5+5
# Out:
# 10

# %%
can = "Bean"

# %%
print(can)
# Out:
# Bean

# %%
type(can)
# Out:
# str

# %%
pizza=100

# %%
pizza
# Out:
# 100

# %%
type(pizza)
# Out:
# int

# %%
samosa=20.5
ice_cream=100

# %%
total=pizza+samosa+ice_cream

# %%
total
# Out:
# 220.5

# %%
type(total)
# Out:
# float

# %%
total > 200
# Out:
# True

# %%
total<200
# Out:
# False

# %%
above_thresold = total > 200
above_thresold
# Out:
# True

# %%
can
# Out:
# 'Bean'

# %%
type(can)
# Out:
# str

# %%
can=607

# %%
foo="jalebi"

# %%
bar=foo

# %%
bar
# Out:
# 'jalebi'
