# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranil199/100-days-of-code_py/blob/main/cb_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
base= 10
height=7
area= (base*height)/2
area
# Out:
# 35.0

# %%
type(area)
# Out:
# float

# %%
x=10
y=3

# %%
x+y
# Out:
# 13

# %%
x-y
# Out:
# 7

# %%
x/y
# Out:
# 3.3333333333333335

# %%
x*y
# Out:
# 30

# %%
x//y #gives division without integer
# Out:
# 3

# %%
x%y #gives reminder after division
# Out:
# 1

# %%
x, y
# Out:
# (10, 3)

# %%
x**y
# Out:
# 1000

# %%
10+2*3 #BODMAS rule
# Out:
# 16

# %%
(10+2)*3
# Out:
# 36

# %%
foo=2.3e4 #scientific notation

# %%
foo
# Out:
# 23000.0

# %%
zoo=2.3e5
zoo
# Out:
# 230000.0

# %%
bar=2.3e-3
bar
# Out:
# 0.0023

# %%
food= 120.34
rent=500.4
utilities=200.5
total=food+rent+utilities
total
# Out:
# 821.24

# %%
round(total)
# Out:
# 821

# %%
round(total,2)
# Out:
# 821.24

# %%
round(total,1)
# Out:
# 821.2

# %%
income=10000
expences=9000
savings=income-expences

# %%
savings
# Out:
# 1000

# %%
food = '120.34'
rent= '500.67'

#Convert strings to floats
total = float(food) + float(rent)
total
# Out:
# 621.01

# %%
import math
x=16
math.sqrt(x)
# Out:
# 4.0

# %%
math.floor(3.7)
# Out:
# 3

# %%
math.ceil(3.7)
# Out:
# 4

# %%
math.pi
# Out:
# 3.141592653589793

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
format(5, 'b')
# Out:
# '101'
