# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranil199/100-days-of-code_py/blob/main/CB_strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first= 'Mohan'
last= "Sharma"
type(first)
# Out:
# str

# %%
name = first +" " + last

# %%
name
# Out:
# 'Mohan Sharma'

# %%
name = f"{first} {last}" #function
name
# Out:
# 'Mohan Sharma'

# %%
age = 28
info = f"{name} {last} is {age} years old"
info         #f'(variable)' is a formatting technique caled f string for easier and more readable string composition in python
# Out:
# 'Mohan Sharma Sharma is 28 years old'

# %%
name[0] #Slice operator
# Out:
# 'M'

# %%
name[1]
# Out:
# 'o'

# %%
name[2]
# Out:
# 'h'

# %%
name[3]
# Out:
# 'a'

# %%
name[0:5]
# Out:
# 'Mohan'

# %%
name[6:12] # slice operator starts with 0
# Out:
# 'Sharma'

# %%
name[-1] #negative means from the end
# Out:
# 'a'

# %%
len(name) # to get the size use len function in this case how many characters
# Out:
# 12

# %%
name
# Out:
# 'Mohan Sharma'

# %%
food_story= "Dhaval's favorite food is banana"

# %%
s = 'he said "oops"'

# %%
recipe = "Veg biryani with saffron, cardamom, and cloves garnished with onion and corriander"
recipe
# Out:
# 'Veg biryani with saffron, cardamom, and cloves garnished with onion and corriander'

# %%
recipe = '''
Veg biryani with saffron, cardamom, and cloves garnished with onion and corriander
'''
#use this technique when multiple lines are there as in if the text is long

# %%
recipe
# Out:
# '\nVeg biryani with saffron, cardamom, and cloves garnished with onion and corriander\n'

# %%
print(recipe)
# Out:
# Veg biryani with saffron, cardamom, and cloves garnished with onion and corriander

# %%
spice = 'cardamom'

# %%
spice in recipe
# Out:
# True

# %%
"milk" in recipe
# Out:
# False

# %%
recipe.find(spice)
# Out:
# 27

# %%
dir(s)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
s= "patient was charged 100$ for lab test"

# %%
s
# Out:
# 'patient was charged 100$ for lab test'

# %%
s.replace("100$", "10$")
# Out:
# 'patient was charged 10$ for lab test'

# %%
s #there is no change cause its done in new string so as to replace do"s= s.replace("100$", "10$")"
# Out:
# 'patient was charged 100$ for lab test'

# %%
s= s.replace("100$", "10$")

# %%
s
# Out:
# 'patient was charged 10$ for lab test'

# %%
s.upper()
# Out:
# 'PATIENT WAS CHARGED 10$ FOR LAB TEST'

# %%
s.lower()
# Out:
# 'patient was charged 10$ for lab test'

# %%
'410'.isdigit()
# Out:
# True

# %%
'a410'.isdigit()
# Out:
# False

# %%
s.index("10$")
# Out:
# 20

# %%
text= "my age is:"
age= 28

# %%
text + str(age)
# Out:
# 'my age is:28'

# %%
s= 'hey\tbro'

# %%
s
# Out:
# 'hey\tbro'

# %%
ticker= 'AAPL|NVDA|RIL|GOGL'

# %%
ticker.split("|", maxsplit=2) #In Python, the split() method is a built-in string function used to break a single string into a list of smaller strings (substrings) based on a specified separator.
# Out:
# ['AAPL', 'NVDA', 'RIL|GOGL']

# %%
ticker.split("|", maxsplit=3)
# Out:
# ['AAPL', 'NVDA', 'RIL', 'GOGL']

# %%
data = "   Hey, we hav to go there, you coming der   "
data
# Out:
# '   Hey, we hav to go there, you coming der   '

# %%
data.strip() #In Python, the strip() method is a built-in string function used to remove specific characters from the beginning (leading) and end (trailing) of a string.
# Out:
# 'Hey, we hav to go there, you coming der'

# %%
file_name="report.pdf"

# %%
file_name.endswith(".pdf")
# Out:
# True
