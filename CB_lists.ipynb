# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranil199/100-days-of-code_py/blob/main/CB_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
item1= 'bread'
item2= 'pasta'
item3= 'cheese'
item4= 'veggies'

# %%
items =['bread','pasta', 'cheese', 'veggies']

# %%
items
# Out:
# ['bread', 'pasta', 'cheese', 'veggies']

# %%
items[0]
# Out:
# 'bread'

# %%
items[3]
# Out:
# 'veggies'

# %%
items[0:2] #split operator
# Out:
# ['bread', 'pasta']

# %%
items.append('butter')#In Python, the append() method is a built-in function specifically used with lists. It adds a single new item to the very end of an existing list.

# %%
items
# Out:
# ['bread', 'pasta', 'cheese', 'veggies', 'butter']

# %%
items. remove('butter')
items
# Out:
# ['bread', 'butter', 'pasta', 'cheese', 'veggies']

# %%
items.insert(1, "butter")
items
# Out:
# ['bread', 'butter', 'butter', 'pasta', 'cheese', 'veggies']

# %%
items[1] ='cheese'

# %%
items[3:]=['alomonds']

# %%
items
# Out:
# ['bread', 'cheese', 'pasta', 'alomonds']

# %%
'rice' in items
# Out:
# False

# %%
expenses = [30,120,45,30]
expenses.sort(reverse=True)
expenses
# Out:
# [120, 45, 30, 30]

# %%
food_items=['bread','pasta', 'fruits']
bathroom_items=["shampoo", "soap"]

# %%
items = food_items + bathroom_items

# %%
items
# Out:
# ['bread', 'pasta', 'fruits', 'shampoo', 'soap']

# %%
len(items)
# Out:
# 5

# %%
dir(items)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
items.clear()
items
# Out:
# []
